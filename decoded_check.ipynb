# %%
import torch

# %%
loaded = torch.load("/home/jongmin/userdata/MAESTRO/maestro-v3.0.0/2006/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_01_Track01_wav_encodec_decoded.pth")

# %%
loaded[0].shape
# Out:
# torch.Size([1, 1, 960000])

# %%
import IPython.display as ipd

# %%
ipd.Audio(loaded[0].squeeze().numpy(), rate=32000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
